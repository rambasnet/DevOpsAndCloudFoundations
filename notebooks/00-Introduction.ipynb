# %% [markdown]
# # Table of Contents
#
# ## Linux Basics
# ### [Learning the Shell](./LearningShell.ipynb)
# ### [Navigating the File System](./NavigatingFileSystem.ipynb)
# ### [Managing Files and Directories](./ManagingFilesAndDirectories.ipynb)
# ### [File Permissions](./FilePermissions.ipynb)
# ### [Expansion and Substitution](./ExpansionAndSubstitution.ipynb)
# ### [IO Redirection & Piplines](./IORedirection-Pipelines.ipynb)
# ### [Jobs & Processeses](./JobsAndProcesses.ipynb)
#
# ## Bash/Shell Scripting
# ### [Bash Script Intro](./BashScriptingIntro.ipynb)
# ### [Functions](./Functions.ipynb)
# ### [Basic Arithmetic](./BasicArithmetic.ipynb)
# ### [Conditionals And Branching](./ConditionalsAndBranching.ipynb)
# ### [Loops and Iteration](./LoopsAndIteration.ipynb)
# ### [Arrays](./Arrays.ipynb)
#
# ## Docker and Containers
# ### [Docker Basics](./DockerBasics.ipynb)
#
# ## Miscellaneous
# ### [Git and Best Practices](./GitAndBestPractices.ipynb)
# ### [Common Linux Commands](./CommonLinuxCommands.ipynb)
